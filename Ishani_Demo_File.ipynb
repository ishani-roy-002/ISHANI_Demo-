# %% [markdown]
# <a href="https://colab.research.google.com/github/ishani-roy-002/ISHANI_Demo-/blob/main/Ishani_Demo_File.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
user_input=input("Enter DNA sequence:")
print(user_input)
# Out:
# Enter DNA sequence:ATGCGGTTGCATGAC
# ATGCGGTTGCATGAC

# %%
total_length=len(user_input)
print(total_length)
# Out:
# 15

# %%
print(f"Sequence_length:{total_length} bases")
# Out:
# Sequence_length:15 bases

# %%
rna_sequences=user_input.replace("T","U")
print(rna_sequences)
# Out:
# AUGCGGUUGCAUGAC
